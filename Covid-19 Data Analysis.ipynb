# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('worldometer_data.csv')

# %%
data
# Out:
#        Country/Region          Continent    Population  TotalCases  NewCases  \
# 0                 USA      North America  3.310234e+08     2936175     405.0
# 1              Brazil      South America  2.125747e+08     1578376       NaN
# 2              Russia             Europe  1.459353e+08      681251    6736.0
# 3               India               Asia  1.380123e+09      675453    1549.0
# 4                Peru      South America  3.297490e+07      299080       NaN
# ..                ...                ...           ...         ...       ...
# 204      Vatican City             Europe  8.010000e+02          12       NaN
# 205        Montserrat      North America  4.992000e+03          11       NaN
# 206  Papua New Guinea  Australia/Oceania  8.947704e+06          11       NaN
# 207    Western Sahara             Africa  5.973540e+05          10       NaN
# 208        MS Zaandam                NaN           NaN           9       NaN
#
# ...

# %%
data.drop(['Serious,Critical', 'Tot Cases/1M pop', 'Deaths/1M pop', 'Tests/1M pop', 'WHO Region', 'NewRecovered','NewDeaths'], axis=1, inplace=True)

# %%
data
# Out:
#        Country/Region          Continent    Population  TotalCases  NewCases  \
# 0                 USA      North America  3.310234e+08     2936175     405.0
# 1              Brazil      South America  2.125747e+08     1578376       NaN
# 2              Russia             Europe  1.459353e+08      681251    6736.0
# 3               India               Asia  1.380123e+09      675453    1549.0
# 4                Peru      South America  3.297490e+07      299080       NaN
# ..                ...                ...           ...         ...       ...
# 204      Vatican City             Europe  8.010000e+02          12       NaN
# 205        Montserrat      North America  4.992000e+03          11       NaN
# 206  Papua New Guinea  Australia/Oceania  8.947704e+06          11       NaN
# 207    Western Sahara             Africa  5.973540e+05          10       NaN
# 208        MS Zaandam                NaN           NaN           9       NaN
#
# ...

# %%
data.head()
# Out:
#   Country/Region      Continent    Population  TotalCases  NewCases  \
# 0            USA  North America  3.310234e+08     2936175     405.0
# 1         Brazil  South America  2.125747e+08     1578376       NaN
# 2         Russia         Europe  1.459353e+08      681251    6736.0
# 3          India           Asia  1.380123e+09      675453    1549.0
# 4           Peru  South America  3.297490e+07      299080       NaN
#
#    TotalDeaths  TotalRecovered  ActiveCases  TotalTests
# 0     132327.0       1260619.0    1543229.0  36955038.0
# 1      64365.0        978615.0     535396.0   3330562.0
# 2      10161.0        450750.0     220340.0  21069457.0
# 3      19303.0        409083.0     247067.0   9789066.0
# 4      10412.0        189621.0      99047.0   1761910.0

# %%
#1.
#data.count()
#data.sum(numeric_only=True)
#data.isnull.sum()

# %%
data.count()
#only the Country/Region and TotalCases columns have not null values at any index
# Out:
# Country/Region    209
# Continent         207
# Population        207
# TotalCases        209
# NewCases           56
# TotalDeaths       183
# TotalRecovered    204
# ActiveCases       205
# TotalTests        188
# dtype: int64

# %%
data.sum(numeric_only=True)
#summing up all the columns data row-wise except string columns
# Out:
# Population        6.319640e+09
# TotalCases        1.132803e+07
# NewCases          3.939700e+04
# TotalDeaths       5.295570e+05
# TotalRecovered    6.176741e+06
# ActiveCases       4.001568e+06
# TotalTests        1.614309e+08
# dtype: float64

# %%
data.isnull().sum()
#the isnull() is a method shoowing which indices are null and sum() method will summarize the total number of null value
# Out:
# Country/Region      0
# Continent           2
# Population          2
# TotalCases          0
# NewCases          153
# TotalDeaths        26
# TotalRecovered      5
# ActiveCases         4
# TotalTests         21
# dtype: int64

# %%
#2
# import matplotlib.pyplot as plt
# import seaborn as sns
# plt.plot(df['Country/Region'], df['TotalDeaths'])
# sns.heatmap(df.isnull())

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-talk')

# %% [markdown]
# # showing TotalCases, TotalRecovered and TotalDeaths bar plots with respect to Country/Region in logarithmic scale

# %%
fig,ax = plt.subplots()
x_index = np.arange(len(data['Country/Region'].head(10)))
width = .3

'''ax.barh(data['Country/Region'].head(10), data['TotalCases'].head(10), width=.4, label='Total Cases')
ax.barh(data['Country/Region'].head(10), data['TotalRecovered'].head(10), width=.4, label='Total Recovered')
ax.barh(data['Country/Region'].head(10), data['TotalDeaths'].head(10), width=.4, label='Total Deaths')'''

ax.bar(x_index-width, data['TotalCases'].head(10), width=.3, color='#2e52a6', label='Total Cases', alpha=.75)
ax.bar(x_index, data['TotalRecovered'].head(10), width=.3, color='#12e66e', label='Total Recovered', alpha=.75)
ax.bar(x_index+width, data['TotalDeaths'].head(10), width=.3, color='#fa232e', label='Total Deaths', alpha=.75)

ax.set_title('Covid-19 status of Top 10 Countries')
ax.set_xlabel('Country')
ax.set_ylabel('Numbers in Log Scale')
ax.legend(loc='upper right')

plt.xticks(ticks=x_index, labels=data['Country/Region'].head(10), rotation=45)
plt.yscale('log')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Depicting the Heatmap of isnull values

# %%
import seaborn as sns

# %%
sns.heatmap(data.isnull())
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Remove all the countries where totalcases less than 1 million

# %%
mask = data.TotalTests<1000000
data = data[~mask]
data[data['TotalTests'].notnull()]
valid = data.notnull()
data = data[valid.TotalTests]
data
# Out:
#    Country/Region          Continent    Population  TotalCases  NewCases  \
# 0             USA      North America  3.310234e+08     2936175     405.0
# 1          Brazil      South America  2.125747e+08     1578376       NaN
# 2          Russia             Europe  1.459353e+08      681251    6736.0
# 3           India               Asia  1.380123e+09      675453    1549.0
# 4            Peru      South America  3.297490e+07      299080       NaN
# 5           Spain             Europe  4.675502e+07      297625       NaN
# 6           Chile      South America  1.911774e+07      291847       NaN
# 7              UK             Europe  6.788994e+07      284900       NaN
# 9           Italy             Europe  6.046055e+07      241419       NaN
# 10           Iran               Asia  8.400069e+07      240438    2560.0
# 11       Pakistan               Asia  2.209085e+08      228474    3191.0
# 12   Saudi Arabia               Asia  3.481700e+07      205929       NaN
# ...

# %% [markdown]
# # Finding the median, standard deviation of TotalCases, TotalDeaths, TotalRecovered

# %%
data.describe()
# Out:
#          Population    TotalCases     NewCases    TotalDeaths  TotalRecovered  \
# count  2.900000e+01  2.900000e+01    11.000000      29.000000    2.700000e+01
# mean   1.109817e+08  3.174559e+05  1508.090909   15153.586207    1.872425e+05
# std    2.551929e+08  5.927424e+05  2046.496883   27346.252303    2.960814e+05
# min    5.792444e+06  6.750000e+03    61.000000      31.000000    2.100000e+03
# 25%    1.911774e+07  4.356900e+04   158.500000     418.000000    2.079650e+04
# 50%    3.784602e+07  1.879770e+05   405.000000    5206.000000    7.706000e+04
# 75%    8.378717e+07  2.849000e+05  2054.500000   11571.000000    1.907825e+05
# max    1.380123e+09  2.936175e+06  6736.000000  132327.000000    1.260619e+06
#
#         ActiveCases    TotalTests
# count  2.700000e+01  2.900000e+01
# mean   1.185659e+05  4.657003e+06
# std    3.062337e+05  7.478340e+06
# min    4.090000e+02  1.059299e+06
# 25%    1.068300e+04  1.326055e+06
# 50%    1.995300e+04  1.792078e+06
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29 entries, 0 to 78
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country/Region  29 non-null     object
#  1   Continent       29 non-null     object
#  2   Population      29 non-null     float64
#  3   TotalCases      29 non-null     int64
#  4   NewCases        11 non-null     float64
#  5   TotalDeaths     29 non-null     float64
#  6   TotalRecovered  27 non-null     float64
#  7   ActiveCases     27 non-null     float64
#  8   TotalTests      29 non-null     float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 2.3+ KB

# %% [markdown]
# # Country with the highest percentage of TotalCases

# %%
data['Ratio'] = (data['TotalCases']/data['Population'])*100
data
# Out:
#    Country/Region          Continent    Population  TotalCases  NewCases  \
# 0             USA      North America  3.310234e+08     2936175     405.0
# 1          Brazil      South America  2.125747e+08     1578376       NaN
# 2          Russia             Europe  1.459353e+08      681251    6736.0
# 3           India               Asia  1.380123e+09      675453    1549.0
# 4            Peru      South America  3.297490e+07      299080       NaN
# 5           Spain             Europe  4.675502e+07      297625       NaN
# 6           Chile      South America  1.911774e+07      291847       NaN
# 7              UK             Europe  6.788994e+07      284900       NaN
# 9           Italy             Europe  6.046055e+07      241419       NaN
# 10           Iran               Asia  8.400069e+07      240438    2560.0
# 11       Pakistan               Asia  2.209085e+08      228474    3191.0
# 12   Saudi Arabia               Asia  3.481700e+07      205929       NaN
# ...

# %%
data.sort_values('Ratio', ascending=False).head() # Chile has the highest ratio
# Out:
#    Country/Region      Continent   Population  TotalCases  NewCases  \
# 6           Chile  South America   19117735.0      291847       NaN
# 4            Peru  South America   32974896.0      299080       NaN
# 0             USA  North America  331023450.0     2936175     405.0
# 1          Brazil  South America  212574666.0     1578376       NaN
# 25        Belarus         Europe    9449280.0       63270       NaN
#
#     TotalDeaths  TotalRecovered  ActiveCases  TotalTests     Ratio
# 6        6192.0        257445.0      28210.0   1163880.0  1.526577
# 4       10412.0        189621.0      99047.0   1761910.0  0.906993
# 0      132327.0       1260619.0    1543229.0  36955038.0  0.886999
# 1       64365.0        978615.0     535396.0   3330562.0  0.742504
# 25        418.0         50669.0      12183.0   1059299.0  0.669575

# %%
d
